# %%
pip install Spotipy
# Out:
# Requirement already satisfied: Spotipy in c:\programdata\miniconda\lib\site-packages (2.16.1)
# Requirement already satisfied: requests>=2.20.0 in c:\programdata\miniconda\lib\site-packages (from Spotipy) (2.22.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\dis\appdata\roaming\python\python37\site-packages (from Spotipy) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dis\appdata\roaming\python\python37\site-packages (from requests>=2.20.0->Spotipy) (2020.11.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\miniconda\lib\site-packages (from requests>=2.20.0->Spotipy) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\miniconda\lib\site-packages (from requests>=2.20.0->Spotipy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\miniconda\lib\site-packages (from requests>=2.20.0->Spotipy) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import spotipy
from pandas.io.json import json_normalize

# %%
username='a06fww0i1c3klv1urrq8ljmlv' 
scope = 'user-library-read user-top-read'
client_id = 'e7d0b9a4df8e4f23be14e77f5537307c'
client_secret = '0543a7534dd0433793c35f4231871257'
redirect_uri = 'http://localhost:7000/callback/'

tk = spotipy.util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)

# %%
sp = spotipy.Spotify(auth=tk)

# %% [markdown]
# # get top artist

# %%
ARTISTS_SAMPLE_SIZE=20
ARTISTS_OFFSET=0

# %%
st_artists = sp.current_user_top_artists(limit=ARTISTS_SAMPLE_SIZE, offset=ARTISTS_OFFSET, time_range='short_term')
mt_artists = sp.current_user_top_artists(limit=ARTISTS_SAMPLE_SIZE, offset=ARTISTS_OFFSET, time_range='medium_term')
lt_artists = sp.current_user_top_artists(limit=ARTISTS_SAMPLE_SIZE, offset=ARTISTS_OFFSET, time_range='long_term')

# %%
short_term_top_artists_df = json_normalize(st_artists["items"])
medium_term_top_artists_df = json_normalize(mt_artists["items"])
long_term_top_artists_df = json_normalize(lt_artists["items"])

# %%
short_term_top_artists_df = short_term_top_artists_df[['name','popularity','genres', 'followers.total', 'uri']].sort_values(by=['popularity'], ascending=False)
medium_term_top_artists_df = medium_term_top_artists_df[['name','popularity','genres', 'followers.total', 'uri']].sort_values(by=['popularity'], ascending=False)
long_term_top_artists_df = long_term_top_artists_df[['name','popularity','genres', 'followers.total', 'uri']].sort_values(by=['popularity'], ascending=False)

# %% [markdown]
# ## short term

# %%
short_term_top_artists_df.head(50)
# Out:
#                     name  popularity  \
# 17  Bring Me The Horizon          81
# 10      Sarcastic Sounds          71
# 9             Sam Fender          65
# 8                Wun Two          65
# 1               BluntOne          64
# 15             Goth Babe          61
# 6                A L E X          61
# 2   In Love With a Ghost          60
# 16               FloFilz          60
# 0              City Girl          59
# 19                Arbour          59
# 5                   Smuv          58
# 4                   Mujo          57
# 3            fantompower          56
# 14           Smoke Trees          55
# 7             Cloudchord          54
# 11                  Nito          51
# 12            leaf beach          49
# 18         Danny Worsnop          48
# 13                JYOCHO          34
#
#                                                genres  followers.total  \
# 17  [melodic metalcore, metalcore, rock, uk metalc...          3378396
# 10                         [lo-fi beats, lo-fi chill]           100633
# 9   [modern alternative rock, modern rock, north e...           304676
# 8                             [chillhop, lo-fi beats]            64853
# 1                             [chillhop, lo-fi beats]            17296
# 15  [indie garage rock, indie pop, indie rock, mod...           119467
# 6                             [chillhop, lo-fi beats]            42156
# 2                   [kawaii future bass, lo-fi beats]           225597
# 16             [chillhop, jazz boom bap, lo-fi beats]            46120
# 0                                       [lo-fi beats]           100350
# 19                            [chillhop, lo-fi beats]            15556
# 5                             [chillhop, lo-fi beats]             7176
# 4   [chillhop, focus beats, japanese chillhop, lo-...            15082
# 3                             [chillhop, lo-fi beats]            10924
# 14             [chillhop, jazz boom bap, lo-fi beats]            19742
# 7                             [chillhop, lo-fi beats]            11329
# 11                                                 []            65471
# 12  [chillhop, focus beats, jazz boom bap, lo-fi b...             8516
# 18                                                 []            37008
# 13  [japanese emo, japanese indie rock, japanese j...            18659
#
#                                       uri
# 17  spotify:artist:1Ffb6ejR6Fe5IamqA5oRUF
# 10  spotify:artist:1bq8rqNnfrojn0OSAfeNXJ
# 9   spotify:artist:6zlR5ttMfMNmwf2lecU9Cc
# 8   spotify:artist:69cjjIQEN8M6heOBT2SqZE
# 1   spotify:artist:225l1KEprObX8xgl8xo2Gc
# 15  spotify:artist:7o96HO2zrujyATtVsqGhh3
# 6   spotify:artist:3nCJkmgdZQ6l8o828Y3vNQ
# 2   spotify:artist:21tDFddcOFDYmiobTcls2O
# 16  spotify:artist:39ZQx0618UYVBgGTDOJ2ds
# 0   spotify:artist:6yby1ACnfwVigbSSaH3kEQ
# 19  spotify:artist:3pSfwb3p6BVPTYDkNdgxS2
# 5   spotify:artist:0SM6zo7lSdqyplZo6XRX76
# 4   spotify:artist:0vg08N1z9G9LrGLkG1nNDS
# 3   spotify:artist:6psQOFgr41pQ2CiL2CCi47
# 14  spotify:artist:6cN5TvotJoRbhYHoCHw8BI
# 7   spotify:artist:5EjKjFGvMmVUGCfAyDY2lG
# 11  spotify:artist:1v7B6ZWa7QRQS3knn3Jvf4
# 12  spotify:artist:5fQYCNYjrT9c4ZssNrC0gh
# 18  spotify:artist:3FffC7t4yWwOUr0S5fFbkW
# 13  spotify:artist:6VIUbb5oBJPnm2gcYMFBUR

# %%
fig = plt.figure(dpi=200, figsize=(20,6))#20 untuk lebar, 6 untuk panjang dalam satuan inch
ax = plt.gca()
short_term_top_artists_df.plot(kind='bar',x='genres',y='popularity',ax=ax)
plt.show()

# %% [markdown]
# ## Medium term

# %%
medium_term_top_artists_df.head(50)
# Out:
#                     name  popularity  \
# 16     The Neighbourhood          84
# 1   Bring Me The Horizon          81
# 3               The 1975          79
# 13   Nothing But Thieves          71
# 7                  Foals          68
# 10            Sam Fender          65
# 2               BluntOne          64
# 5               Polyphia          63
# 18             City Girl          59
# 6                 Arbour          59
# 14              Flughand          58
# 0                   Smuv          58
# 19      quickly, quickly          58
# 11              Toonorth          56
# 9            fantompower          56
# 12             Knowmadic          55
# 17          Slumberville          55
# 4             leaf beach          49
# 8                  DRWN.          44
# 15          INTI CREATES          33
#
#                                                genres  followers.total  \
# 16        [modern alternative rock, modern rock, pop]          5070503
# 1   [melodic metalcore, metalcore, rock, uk metalc...          3378396
# 3   [modern alternative rock, modern rock, nu gaze...          4595919
# 13  [alternative pop rock, modern alternative rock...           666722
# 7   [alternative dance, indie rock, modern rock, n...          1141573
# 10  [modern alternative rock, modern rock, north e...           304676
# 2                             [chillhop, lo-fi beats]            17296
# 5                                 [instrumental rock]           350436
# 18                                      [lo-fi beats]           100350
# 6                             [chillhop, lo-fi beats]            15556
# 14  [chillhop, focus beats, jazz boom bap, lo-fi b...            26412
# 0                             [chillhop, lo-fi beats]             7176
# 19  [chillhop, future bass, lo-fi beats, portland ...            45857
# 11                            [chillhop, lo-fi beats]            13776
# 9                             [chillhop, lo-fi beats]            10924
# 12               [chillhop, focus beats, lo-fi beats]            23785
# 17                                      [lo-fi beats]             4529
# 4   [chillhop, focus beats, jazz boom bap, lo-fi b...             8516
# 8                             [chillhop, lo-fi beats]             8403
# 15                                     [japanese vgm]              446
#
#                                       uri
# 16  spotify:artist:77SW9BnxLY8rJ0RciFqkHh
# 1   spotify:artist:1Ffb6ejR6Fe5IamqA5oRUF
# 3   spotify:artist:3mIj9lX2MWuHmhNCA7LSCW
# 13  spotify:artist:1kDGbuxWknIKx4FlgWxiSp
# 7   spotify:artist:6FQqZYVfTNQ1pCqfkwVFEa
# 10  spotify:artist:6zlR5ttMfMNmwf2lecU9Cc
# 2   spotify:artist:225l1KEprObX8xgl8xo2Gc
# 5   spotify:artist:4vGrte8FDu062Ntj0RsPiZ
# 18  spotify:artist:6yby1ACnfwVigbSSaH3kEQ
# 6   spotify:artist:3pSfwb3p6BVPTYDkNdgxS2
# 14  spotify:artist:6x5HLaMcoxaULXpgN0NJbb
# 0   spotify:artist:0SM6zo7lSdqyplZo6XRX76
# 19  spotify:artist:5XTn5Az9AcSKu0oaauC5ES
# 11  spotify:artist:5cnRXRa8otbppSiXvfdmo3
# 9   spotify:artist:6psQOFgr41pQ2CiL2CCi47
# 12  spotify:artist:0HcyeAioEKhfwVcJAoyN36
# 17  spotify:artist:2c0SyAUT82Al3gJQ3uezBv
# 4   spotify:artist:5fQYCNYjrT9c4ZssNrC0gh
# 8   spotify:artist:0h6JSIfoSSbXtaBWiUC4Wy
# 15  spotify:artist:09qQ7egbiup9i53g7IbKkq

# %% [markdown]
# ## Long terms

# %%
long_term_top_artists_df.head(50)
# Out:
#                     name  popularity  \
# 4             Ed Sheeran          91
# 17              Maroon 5          87
# 3         Arctic Monkeys          86
# 0   Bring Me The Horizon          81
# 11          Foo Fighters          79
# 18              The 1975          79
# 5      Rex Orange County          79
# 14          All Time Low          75
# 16                 HONNE          72
# 13             Pamungkas          71
# 1      Asking Alexandria          70
# 19           Bruno Major          69
# 10     Dance Gavin Dance          68
# 7         Our Last Night          67
# 6        Daniela Andrade          67
# 2            Sheila On 7          67
# 8       Imaginary Future          64
# 15             Beartooth          63
# 9              Kunto Aji          62
# 12            Polka Wars          33
#
#                                                genres  followers.total  \
# 4                                       [pop, uk pop]         73838714
# 17                                    [pop, pop rock]         28511266
# 3   [garage rock, modern rock, permanent wave, roc...         10408888
# 0   [melodic metalcore, metalcore, rock, uk metalc...          3378396
# 11  [alternative metal, alternative rock, modern r...          8247558
# 18  [modern alternative rock, modern rock, nu gaze...          4595919
# 5                                  [bedroom pop, pop]          2615013
# 14       [modern rock, pop punk, post-teen pop, rock]          2449771
# 16                                      [pop, uk pop]          1078245
# 13                                   [indonesian pop]           582369
# 1   [melodic metalcore, metalcore, trancecore, uk ...          1548444
# 19                              [indie cafe pop, pop]           481498
# 10  [metalcore, pixie, pop punk, sacramento indie,...           467448
# 7   [metalcore, modern rock, pop punk, post-scream...           660808
# 6               [canadian contemporary r&b, folk-pop]           343603
# 2   [indonesian alternative rock, indonesian indie...          3416530
# 8   [acoustic pop, folk-pop, indie cafe pop, indie...           103851
# 15                        [modern rock, post-screamo]           480966
# 9   [indonesian indie, indonesian jazz, indonesian...           351394
# 12                                 [indonesian indie]            28692
#
#                                       uri
# 4   spotify:artist:6eUKZXaKkcviH0Ku9w2n3V
# 17  spotify:artist:04gDigrS5kc9YWfZHwBETP
# 3   spotify:artist:7Ln80lUS6He07XvHI8qqHH
# 0   spotify:artist:1Ffb6ejR6Fe5IamqA5oRUF
# 11  spotify:artist:7jy3rLJdDQY21OgRLCZ9sD
# 18  spotify:artist:3mIj9lX2MWuHmhNCA7LSCW
# 5   spotify:artist:7pbDxGE6nQSZVfiFdq9lOL
# 14  spotify:artist:46gyXjRIvN1NL1eCB8GBxo
# 16  spotify:artist:0Vw76uk7P8yVtTClWyOhac
# 13  spotify:artist:7d86ERlvO5UG44j7Va0Y0C
# 1   spotify:artist:1caBfBEapzw8z2Qz9q0OaQ
# 19  spotify:artist:0hDjKSKjl1DC7ovYTDJHe8
# 10  spotify:artist:6guC9FqvlVboSKTI77NG2k
# 7   spotify:artist:00YTqRClk82aMchQQpYMd5
# 6   spotify:artist:0WfaItAbs4vlgIA1cuqGtJ
# 2   spotify:artist:6q87vizIEdEN4NvlR6mjfT
# 8   spotify:artist:470WlqN9HSRDGNaMufeHHF
# 15  spotify:artist:6vwjIs0tbIiseJMR3pqwiL
# 9   spotify:artist:7dfFM5cBUOBmOH08sGNDcy
# 12  spotify:artist:18ss7hrVwa5Wgb278tcy8d

# %%
fig = plt.figure(dpi=200, figsize=(20,6))#20 untuk lebar, 6 untuk panjang dalam satuan inch
ax = plt.gca()
long_term_top_artists_df.plot(kind='bar',x='name',y='popularity',ax=ax)
plt.show()

# %% [markdown]
# # get top tracks

# %%
TRACKS_SAMPLE_SIZE = 1000
TRACKS_OFFSET = 0

# %%
st_tracks = sp.current_user_top_tracks(limit=TRACKS_SAMPLE_SIZE, offset=TRACKS_OFFSET, time_range='short_term')
mt_tracks = sp.current_user_top_tracks(limit=TRACKS_SAMPLE_SIZE, offset=TRACKS_OFFSET, time_range='medium_term')
lt_tracks = sp.current_user_top_tracks(limit=TRACKS_SAMPLE_SIZE, offset=TRACKS_OFFSET, time_range='long_term')

# %%
short_term_top_tracks_df = json_normalize(st_tracks["items"])
medium_term_top_tracks_df = json_normalize(mt_tracks["items"])
long_term_top_tracks_df = json_normalize(lt_tracks["items"])

# %%
properNameFunc = lambda raw_col_value: raw_col_value[0]['name']

short_term_top_tracks_df = short_term_top_tracks_df[['artists', 'name','popularity', 'id', 'duration_ms', 'album.name', 'album.release_date']].sort_values(by=['popularity'], ascending=False)
medium_term_top_tracks_df = medium_term_top_tracks_df[['artists', 'name','popularity', 'id', 'duration_ms', 'album.name', 'album.release_date']].sort_values(by=['popularity'], ascending=False)
long_term_top_tracks_df = long_term_top_tracks_df[['artists', 'name','popularity', 'id', 'duration_ms', 'album.name', 'album.release_date']].sort_values(by=['popularity'], ascending=False)

short_term_top_tracks_df['artists'] = short_term_top_tracks_df['artists'].apply(properNameFunc)
medium_term_top_tracks_df['artists'] = medium_term_top_tracks_df['artists'].apply(properNameFunc)
long_term_top_tracks_df['artists'] = long_term_top_tracks_df['artists'].apply(properNameFunc)

# %% [markdown]
# ## short term

# %%
short_term_top_tracks_df.head(50)
# Out:
#                     artists                                              name  \
# 27                    TWICE                                        CRY FOR ME
# 46        The Neighbourhood                                        Stargazing
# 26          BETWEEN FRIENDS                                         affection
# 18                     eery                                               Her
# 42                 The 1975                    I Always Wanna Die (Sometimes)
# 19                 grandson                                           Riptide
# 37        The Neighbourhood                                Over the Influence
# 33          Call Me Karizma                                             Float
# 30                 Labrinth                                         Ave Maria
# 24          Alfie Templeman                          Stop Thinking (About Me)
# 36     Bring Me The Horizon            Doomed - Live at the Royal Albert Hall
# 16  Winnetka Bowling League                                       Slow Dances
# 32                   Arbour                                      Magic--Pearl
# 22      Nothing But Thieves                             Phobia - Wuh Oh Remix
# 31                  H E R B                                            Moving
# 43                  A L E X                                  Sleep Next to Me
# 47     Gesu No Kiwami Otome                                     sad but sweet
# 39                  A L E X                              No One Would Miss Me
# 7                leaf beach                                        Aqua skies
# 1                  BluntOne                               Pillars of Creation
# 28                City Girl                                              Easy
# 21           Declan McKenna                  Hallucinate - In the Live Lounge
# 25            Chance Thrash                                     Chamomile Tea
# 20            Danny Worsnop                                     Say Something
# 41            Del Water Gap                                 Laid Down My Arms
# 38                Absofacto                                        Two Wrongs
# 29              Circa Waves                                   Sorry I'm Yours
# 44                  FloFilz                                          Hau Nalu
# 34               rebelsuns.                                        Over Again
# 23                 BluntOne                                         SensiTeev
# 11                City Girl  To Be Honest I Just Want to Eat Noodles with You
# 13                 The Deli                                             Verde
# 45                    J.Fla                                          Dynamite
# 35              fantompower                                         Constance
# 49         Imaginary Future                                         Two of Us
# 8                     Dweeb                                  '91 Bimmer, Pt.1
# 14                Estugarda                                          Balloons
# 0                  Toonorth                                           Concord
# 2                  BluntOne                                       Bok Globule
# 40            October Drift                                    Oh the Silence
# 9                  Smeyeul.                                          Solitary
# 17              Flitz&Suppe                                    Walk Damn Slow
# 15                Priesemut                                            Street
# 6                     DRWN.                                             Curls
# 4                      Smuv                                   Closed Curtains
# 3                    Otesla                                           Bless U
# 48                     Smuv                                            Soaked
# 5           Keem the Cipher                                   First Movement.
# 12                  Fushou.                                        blue dream
# 10               leaf beach                                         Moonlight
#
#     popularity                      id  duration_ms  \
# 27          77  2xtP8RNbo2BEMzLX7tK7aq       204167
# 46          74  0VF7YLIxSQKyNiFL3X6MmN       217026
# 26          72  2lTtnKQgjbrBA1qnOFhBkP       235225
# 18          66  2koESjC2WBc6qmfg0dmTRt       123219
# 42          65  7iPlcFvOMOzt6v0QvcAueZ       314662
# 19          62  2oAZlBN2CmNieXmJ1bQDYL       192382
# 37          61  5VoBizwMwcd2D68EfqxDbO       220760
# 33          56  54JbP4PgOMQGowCbCfjCNA       169093
# 30          55  3vzqs9tJQx7JoTC2bX7uae       194275
# 24          55  22W4eNzgioQ4Tkz8B3v17a       251061
# 36          55  5IBDi9cISbefMMtAB8syp3       280250
# 16          55  0J8x2FryJyw7OVnEGYNFQE       232280
# 32          53  4hiNXRP0MUIl6wdEMAnazO       200856
# 22          52  7BZGupqhRPoeIguNyYbHUy       184933
# 31          52  4JjpOx1UPqLqnPRGizLgKy        96313
# 43          50  07MZXSRBs5DJxYZiRTFJe8       139911
# 47          49  0cDSDilvrV0MhO6GPU3DoI       344253
# 39          49  5xHwAQiKx72cDuMCVkEF79       173664
# 7           48  7GUFtORUccFTN0bWWKqDOb       102077
# 1           47  5Hq1CQHBuaxjHSCgj6DoUu        96592
# 28          46  35yldEsDkKvcxb9NJ034AI       168500
# 21          45  77p5rVpxLMBHlOtyaOQCbL       218831
# 25          42  249DfaJ8bAvgjsZNV47Llv       142338
# 20          41  6WZeCATy3LJizmYdeqAVbW       280979
# 41          41  6Mxm3G0LA8O7BKeb7TEQZT       269640
# 38          40  5YTzmYWaMCnSBtCodjtxn7       187235
# 29          39  3bol6EKtmVxM4dxkMKwoWk       228998
# 44          39  08yKVprllO3kSSbCq1rtKc       134301
# 34          38  54rPb8R51vR6HVh4u1g0Eh       190839
# 23          34  0VPDFu3Nsfx7cC2o2ISJoh       113510
# 11          34  7FpUGKMaiBj1AmWgufABjJ       234000
# 13          32  5iJsAwuWSZjwfeh4avPpkm       177548
# 45          31  0DgVhLg8UKvizfwZvcX6En       133929
# 35          30  5GYin7KiRv1Wp6FfzzUKf1       168761
# 49          29  1JeGItUaDUTnP2nZkicLnd       182259
# 8           28  03qvygTWSmCQsoiBnIJvrc        67368
# 14          24  5TTWujlDPxCP47SqnRoj6w       152321
# 0           24  5R9irDVOz81aJUGsy57hI1       120804
# 2           23  48U713JHdi8HX20J44pJDW       126634
# 40          22  6GbptQzlV3W1mH0tsVwzdH       210652
# 9           22  2VQnf98GeozsnsYHDDXdwE       154074
# 17          21  0KgGXQZ3IihQB12QfTqgSV       148250
# 15          16  2U5X4DZTt66pOR1q1X7seE        86105
# 6           16  3HdhYDYBnf1m8JPbjaXPyU       128674
# 4           14  1QvK67MAtMpcK6MQ3QN9Xg       151500
# 3           13  0c7OuD13IqvNkGiyzbKPoG       146754
# 48          13  0nFaMFrvJkFSY14TQhQn8v       116750
# 5           11  1vSl6wJA5lDwff3bS2gJeE       127058
# 12           9  1etoVtJLX2Pf6pj45WG9j6       217730
# 10           9  4EPcNXQWZnqS9aTPh5gZOb       136196
#
#                                    album.name album.release_date
# 27                                 CRY FOR ME         2020-12-18
# 46      Chip Chrome & The Mono-Tones (Deluxe)         2020-12-11
# 26            we just need some time together         2018-04-05
# 18                                        Her         2016-01-01
# 42  A Brief Inquiry Into Online Relationships         2018-11-30
# 19                                    Riptide         2020-07-31
# 37      Chip Chrome & The Mono-Tones (Deluxe)         2020-12-11
# 33                                      Float         2020-04-24
# 30                                  Ave Maria         2020-12-04
# 24                      Sunday Morning Cereal         2019-06-21
# 36              Live at the Royal Albert Hall         2020-12-18
# 16                                Slow Dances         2019-04-03
# 32                            Sights & Sounds         2018-02-23
# 22                      Phobia (Wuh Oh Remix)         2020-12-04
# 31                                    Origins         2017-11-11
# 43                         Growing Up, Vol. 1         2017-06-26
# 47                                   好きなら問わない         2018-08-29
# 39                         Growing Up, Vol. 1         2017-06-26
# 7                                  Aqua skies         2017-12-17
# 1                          Space Is the Place         2018-03-01
# 28                                       Easy         2020-09-14
# 21                           Zeros (Stripped)         2020-05-29
# 25                                   Tea Time         2017-09-13
# 20                              Say Something         2020-12-04
# 41                          Laid Down My Arms         2018-11-14
# 38                            Thousand Peaces         2017-11-03
# 29                 What's It Like Over There?         2019-04-05
# 44                                   Hau Nalu         2020-12-02
# 34                                 Over Again         2020-12-11
# 23                                  SensiTeev         2020-12-04
# 11                                  Snow Rose         2017-12-09
# 13                                 Encounters         2017-06-01
# 45                                   Dynamite         2020-09-25
# 35                                  Constance         2020-12-02
# 49                                  Two of Us         2020-12-25
# 8                            '91 Bimmer, Pt.1         2018-04-06
# 14                                       Lava         2018-02-02
# 0                                       Morii         2018-01-16
# 2                          Space Is the Place         2018-03-01
# 40                           Forever Whatever         2020-01-24
# 9                                Lonely Vibes         2018-01-11
# 17                                  Melatonin         2018-03-28
# 15                    Brainwaves on Late Days         2018-04-27
# 6                               Untitled_Five         2018-04-13
# 4                                        Sofa         2018-12-20
# 3                              Evergreen Tape         2018-03-10
# 48                                       Sofa         2018-12-20
# 5                              Slight Return.         2018-03-05
# 12                                  High Noon         2018-03-26
# 10                                    Arrival         2018-05-01

# %% [markdown]
# ## medium term

# %%
medium_term_top_tracks_df.head(50)
# Out:
#               artists                                               name  \
# 37  Twenty One Pilots                                       Stressed Out
# 9          Red Velvet                                             Psycho
# 2               TWICE                                        MORE & MORE
# 40  Asking Alexandria           The Final Episode (Let's Change Channel)
# 27         The Marías                                   Hold It Together
# 22           Polyphia                                               40oz
# 24            Dayglow                                          Nicknames
# 45      Chieko Baisho  Ending Song - The Promise of the World - Merry...
# 11       Jeremy Soule                                             Masser
# 30            Wun Two                                             savacu
# 13         leaf beach                                         Aqua skies
# 1            BluntOne                                Pillars of Creation
# 10           Polyphia                                                LIT
# 3            Polyphia                                             Ignite
# 36               Smuv                                        Sofa Boogie
# 23           The Deli                                              Verde
# 5            BluntOne                                     Misty Sunshine
# 32             PRGMAT                                               Cmnd
# 33              Dweeb                                   '91 Bimmer, Pt.1
# 29         leaf beach                                            Blunted
# 21       Daryl Donald                                              Crown
# 48       Philanthrope                                            Preface
# 26           Too Ugly                                           I0000012
# 15           Toonorth                                            Concord
# 6           Estugarda                                           Balloons
# 0            BluntOne                                        Bok Globule
# 35             Nokiaa                                               Fall
# 19           Smeyeul.                                           Solitary
# 49        Flitz&Suppe                                     Walk Damn Slow
# 38       Joe Corfield                                         Still Life
# 34       Don Philippe                                          Frederlow
# 4           Made in M                                  Good to Go (home)
# 12          Priesemut                                             Street
# 31           Bilo 503                                      singularita t
# 39           Toonorth                                          coco.zola
# 17               Smuv                                    Closed Curtains
# 25              Druid                                            ice age
# 14             Otesla                                            Bless U
# 16               Smuv                                             Soaked
# 41              Dwyer                                           Mind Fog
# 20             Nokiaa                                              Minds
# 18            tusken.                                       haze odyssey
# 42            Fushou.                                         blue dream
# 7          leaf beach                                          Moonlight
# 28               Smuv                                        food heaven
# 46               Smuv                                               mint
# 47           BluntOne                                  Conscious Hoodlum
# 8              Miraa.                                       Outro, Maybe
# 43             Sumwun                                            Coconut
# 44            Fushou.                                              1977.
#
#     popularity                      id  duration_ms  \
# 37          83  3CRDbSIZ4r5MsZ0YwxuEkn       202333
# 9           80  3CYH422oy1cZNoo0GTG1TK       210560
# 2           75  3omvXShuRPM3zbDpWYqf5g       199653
# 40          60  0CqCpm4LLQbHUX5ysizWJS       242080
# 27          59  6gJ2H930mAD1zRqmoFiE4W       222021
# 22          58  3v3VFa7Dt32gNR27jfw7DG       233818
# 24          55  2KfFmPKssYjVxmzUmin1rI       203727
# 45          53  5AVUsyKKPhYJItIVeEqw2E       410466
# 11          50  5qjqvjJQ15sH6dIgXUzg5I       364425
# 30          48  4cRtsgJHnz4UaUnHGfDrxB        94814
# 13          48  7GUFtORUccFTN0bWWKqDOb       102077
# 1           47  5Hq1CQHBuaxjHSCgj6DoUu        96592
# 10          47  3RoycW4yhd2HCsWmLR7xIi       252464
# 3           40  4o6Uwrxpqa9zLxoLUvtQ4Z       112250
# 36          38  6LhbQdJd6Fy2il7VNCHAKj       100416
# 23          32  5iJsAwuWSZjwfeh4avPpkm       177548
# 5           31  1B0s0XuwGBKAFVrLmxC6kE       108664
# 32          29  7CWnQZVftmHGqiiDT9bBZC       158117
# 33          28  03qvygTWSmCQsoiBnIJvrc        67368
# 29          27  63L3A0z2A5DRix83DnHCDX       121942
# 21          25  1AlostOXM1C7MSHY0NDpXY        58695
# 48          25  6VrLbAWWv1JcAlJ9ONwJIL       100000
# 26          25  6g01exIXDrTUIJ7obFiY3y       101900
# 15          24  5R9irDVOz81aJUGsy57hI1       120804
# 6           24  5TTWujlDPxCP47SqnRoj6w       152321
# 0           23  48U713JHdi8HX20J44pJDW       126634
# 35          22  4pL8xRSudfRVC9188Faikc        72000
# 19          22  2VQnf98GeozsnsYHDDXdwE       154074
# 49          21  0KgGXQZ3IihQB12QfTqgSV       148250
# 38          20  7oKSjUEWQoODQvDsVUiglV       126400
# 34          18  3LecSPQYzjodXRwhyPvu5S       133526
# 4           17  7E1Wwt7eeeVqTcl8fhThJL        58437
# 12          16  2U5X4DZTt66pOR1q1X7seE        86105
# 31          16  74qPWFZiZ0IY14JoeKQ1Op       140487
# 39          15  4QE9Exl1q7PraOkvJ7UMq1       140985
# 17          14  1QvK67MAtMpcK6MQ3QN9Xg       151500
# 25          13  3a8IfvZc8lmvYh0VXmmYbL       180571
# 14          13  0c7OuD13IqvNkGiyzbKPoG       146754
# 16          13  0nFaMFrvJkFSY14TQhQn8v       116750
# 41          11  0q8ITR0UQpvn9DGUaLuh66       146500
# 20          10  0Tw8aZw692I16mOXy9B2Bk       101052
# 18          10  69j38YP23TMR73XY2WOtxK       100689
# 42           9  1etoVtJLX2Pf6pj45WG9j6       217730
# 7            9  4EPcNXQWZnqS9aTPh5gZOb       136196
# 28           8  34oXonHiDf3ZqvUblWIWQw       129695
# 46           7  5C83q0v9Bj4IscYoXQtvdH       138057
# 47           7  5XcJWkCAiE8uq8kbjCgik4        51586
# 8            5  0ER9aJEWTnEXEdL7hw7MAh       110293
# 43           4  2UlOUA3vSZGSD2Z5HtXzpy       146845
# 44           4  3bUBOKz8AwUXl0hBBarVmj        73846
#
#                                            album.name album.release_date
# 37                                         Blurryface         2015-05-15
# 9                          ‘The ReVe Festival’ Finale         2019-12-23
# 2                                         MORE & MORE         2020-06-01
# 40                                Stand Up And Scream         2009-09-15
# 27                                   Hold It Together         2020-03-06
# 22                                     The Most Hated         2017-07-14
# 24                                         Fuzzybrain         2019-11-14
# 45                    Howl's Moving Castle Soundtrack         2004-11-19
# 11  The Elder Scrolls V: Skyrim: Original Game Sou...         2013-01-31
# 30                                   bird of paradise         2016-07-17
# 13                                         Aqua skies         2017-12-17
# 1                                  Space Is the Place         2018-03-01
# 10                                                LIT         2017-01-13
# 3                                             Inspire         2013-04-21
# 36                                               Sofa         2018-12-20
# 23                                         Encounters         2017-06-01
# 5                                         Forest Walk         2018-05-18
# 32                                               Cmnd         2018-06-21
# 33                                   '91 Bimmer, Pt.1         2018-04-06
# 29                                            Arrival         2018-05-01
# 21                                           Solitude         2017-12-06
# 48                         Birds of a Feather, Vol. 1         2018-07-23
# 26                                   All That Spinach         2018-05-30
# 15                                              Morii         2018-01-16
# 6                                                Lava         2018-02-02
# 0                                  Space Is the Place         2018-03-01
# 35                                       Fall / Apart         2018-05-16
# 19                                       Lonely Vibes         2018-01-11
# 49                                          Melatonin         2018-03-28
# 38                                            KO-OP 2         2019-02-01
# 34                                         Red Flower         2017-09-29
# 4                                                Nest         2016-11-04
# 12                            Brainwaves on Late Days         2018-04-27
# 31                                            Arecibo         2017-04-01
# 39                                        404sessions         2017-03-21
# 17                                               Sofa         2018-12-20
# 25                                            ice age         2018-04-30
# 14                                     Evergreen Tape         2018-03-10
# 16                                               Sofa         2018-12-20
# 41                                         Night Swim         2017-06-18
# 20                                     Pie in the Sky         2018-05-08
# 18                                              patha         2016-03-30
# 42                                          High Noon         2018-03-26
# 7                                             Arrival         2018-05-01
# 28                                           munchies         2017-09-06
# 46                                     doobie mixture         2017-07-28
# 47                                        Forest Walk         2018-05-18
# 8                                    Under Palm Trees         2015-02-24
# 43                                          La Planta         2018-01-02
# 44                                          organics.         2017-12-31

# %% [markdown]
# ## long top tracks

# %%
long_term_top_tracks_df.head(50)
# Out:
#                            artists                               name  \
# 6                The Neighbourhood                    Sweater Weather
# 2                             Joji           SLOW DANCING IN THE DARK
# 16               Rex Orange County                          Sunflower
# 34                         FINNEAS   Let's Fall in Love for the Night
# 33                       Tom Petty                       Free Fallin'
# 18               Rex Orange County                    Corduroy Dreams
# 39                 Pierce The Veil                     King For A Day
# 5                        boy pablo                          Everytime
# 20            Bring Me The Horizon                             Ludens
# 36                         SAMSONS                  Kenangan Terindah
# 1                    Phum Viphurit                          Lover Boy
# 43            Bring Me The Horizon                             MANTRA
# 8                            Tulus                           Monokrom
# 24               Rex Orange County                            Edition
# 41            Bring Me The Horizon                        in the dark
# 25                      The Marías                           Ruthless
# 38            Bring Me The Horizon                       Shadow Moses
# 9                Rex Orange County                          New House
# 44            Bring Me The Horizon      nihilist blues (feat. Grimes)
# 0                    Phum Viphurit                     Hello, Anxiety
# 45                     beabadoobee                          Disappear
# 28  Heidi (The Girl with the Hair)                       Soon Finland
# 26            Bring Me The Horizon  i apologise if you feel something
# 42                          H.E.R.        Hard Place - Single Version
# 35                     Bruno Major                         On Our Own
# 7                           Hindia                         Secukupnya
# 49                   Phum Viphurit               Strangers in a Dream
# 48            Sleeping With Sirens                     I Need to Know
# 4                            potsu                         turtleneck
# 27                Jasmine Thompson                          take care
# 21              Mustache and Beard               Senyum Membawa Pesan
# 11               Asking Alexandria               Empire (feat. Bingx)
# 13                    Jean Seizure                              Night
# 31               Three Oscillators                           Drowning
# 30            Bring Me The Horizon      nihilist blues (feat. Grimes)
# 46                      Polka Wars          Rangkum - Reprise Version
# 37                  Midnight Fusic                       Time Machine
# 29                   Isobel Knight                        Home Is You
# 15                     Geno Samuel                       Plastic Love
# 12                     Tom's Story              Seyda Neen - Acoustic
# 32                          Priska                      Lost in Japan
# 47                          Rie fu                            Ripples
# 19                    Sam Franklin                   I Don't Need You
# 3                       Polka Wars                               Suar
# 40                       Islandeer                      The Bad Taste
# 22                     Bruno Major                      Old Fashioned
# 23                             FUR        If You Know That I'm Lonely
# 17                       Kunto Aji                              Rehat
# 14              Friday Night Plans                       Plastic Love
# 10                       Kunto Aji                             Sulung
#
#     popularity                      id  duration_ms  \
# 6           89  2QjOHCTQ1Jl3zawyYOpxh6       240400
# 2           85  0rKtyWc8bvkriBthvHKY8d       209273
# 16          78  4EpZ4eYuZOwPSSwyqpdHnJ       252230
# 34          78  7kQkmyoHCEqwe7QwDbkSXM       190348
# 33          78  5tVA6TkbaAH9QMITTQRrNv       256000
# 18          74  02tvc9CFnTyHuSRlGeNv9w       206974
# 39          72  1IT0WQk5J8NsaeII8ktdlZ       236293
# 5           68  4zvHZWOGyL7WcmqHOgtGCW       172941
# 20          68  2eZjO58Qe9og2xmyfw4qwJ       280151
# 36          66  5TtmfZaNSYEcTR49cureT0       247000
# 1           65  2rd4FH1cSaWGc0ZiUaMbX9       236727
# 43          65  060RNnzoMay3wKJek1faPc       233128
# 8           65  4GfK1qOF3uBWidbPlTCQRL       214567
# 24          64  1wz7B02oOtrTW6SNLG0cSk       115000
# 41          63  4swVflM7KtMxzfHBWqPv9S       271186
# 25          62  1mbuSss0OVqfS00y7yCNCZ       247455
# 38          62  68osIGtVjM7QWVe6pazLHj       243320
# 9           61  79yScU3wNnv2yPF3awYqnU       199052
# 44          60  1JdWRS3PBZlSgKcPKcULtr       325501
# 0           59  1ZseaIKt19broBzze3F8hz       264761
# 45          56  1vKPCcclqSIHpMIh4YieQG       248883
# 28          55  2mpPBZRP0EaFx3NnChQ6ru       218426
# 26          54  4mrjzz6ETpW3wosJUYmKoL       139563
# 42          53  56Rmib5mhCfiaSJqhLgEdW       210303
# 35          52  1FR7sSXjt4lCN965GvR5ym       189128
# 7           51  4RGeIxGrN9VH1TJ94ppyje       208823
# 49          46  0bnGpP5DSgTy4JCJqUhrxY       205624
# 48          45  6gCPwhhn9vmlVHxo6JGmQO       217626
# 4           45  3Oz20Z27pBBTHVf4aGW6Cq       110254
# 27          43  2kjZc9M1lN5ZMAyWesfUPs       178737
# 21          43  41UGZgEAFF6jt8OSa1XG8B       312000
# 11          41  5VFn8MjsHQflkA05ytR7OJ       256621
# 13          39  3XSfox2hhuvvFE5vSOX32r       201010
# 31          39  5yOy3vK27xjkWaqTS46gHN       216055
# 30          33  6kK1tvN0YOoUnRFM1NSjsL       325506
# 46          33  02pa4PtbBal2893oJRnRfj       268266
# 37          32  5zkpedSSD6VtfwHOwQIHZV       322447
# 29          30  5AgGFHJzCzcn2l94yqe0fk       188521
# 15          22  22OGhrVHUarlxoORTSjgqu       371206
# 12          20  7sy1bXnWyz7gLsxEsmywaE       337548
# 32          16  5zYDqJfwOhfeac4RU8wSVX       159157
# 47          16  6956P25CJKhe6LBQYrSp2p       225741
# 19          15  5EBneM2zRyQ4EqaYf3uHHi       249729
# 3            9  6teogdAwI7JOKPgiVBEh3F       264506
# 40           8  3ARvfotukFEY50LU0uRdMM       224312
# 22           3  2N0rHlYG5N4fN9HnVis9yj       199903
# 23           2  0lvosDfrUEI07fTwQotQOv       166500
# 17           2  1BzMyhmPzYnGWK6RBF5TTj       354480
# 14           0  1DBqmybmBZiJ0N98hbthPD       275891
# 10           0  7qo8kexwXhr3FwyHASzvvk       113906
#
#                           album.name album.release_date
# 6                        I Love You.         2013-04-19
# 2                          BALLADS 1         2018-10-26
# 16                         Sunflower         2017-03-22
# 34  Let’s Fall In Love For The Night         2018-10-19
# 33                   Full Moon Fever         1989-01-01
# 18          Bcos U Will Never B Free         2016-11-07
# 39              Collide With The Sky         2012-07-17
# 5                          Roy Pablo         2017-05-19
# 20                            Ludens         2019-11-06
# 36   Naluri Lelaki (Special Edition)         2016-09-21
# 1                          Lover Boy         2018-03-22
# 43                               amo         2019-01-25
# 8                           Monokrom         2016-08-03
# 24                           Edition         2017-09-12
# 41                               amo         2019-01-25
# 25               Superclean, Vol. II         2018-09-28
# 38    Sempiternal (Expanded Edition)         2013-04-01
# 9                          New House         2019-02-14
# 44                               amo         2019-01-25
# 0                     Hello, Anxiety         2019-03-22
# 45                          Loveworm         2019-04-26
# 28                      Soon Finland         2018-04-27
# 26                               amo         2019-01-25
# 42                        Hard Place         2019-02-25
# 35             A Song For Every Moon         2017-08-31
# 7                         Secukupnya         2019-05-03
# 49                          Manchild         2017-02-04
# 48                            Gossip         2017-09-22
# 4                         ivy league         2019-02-23
# 27                         take care         2019-03-01
# 21    Manusiaku Manusiamu Manusianya         2016-01-01
# 11                 Asking Alexandria         2017-12-15
# 13                             Night         2018-04-21
# 31                          Drowning         2019-03-19
# 30     nihilist blues (feat. Grimes)         2019-01-24
# 46         Rangkum (Reprise Version)         2018-04-13
# 37           When Love Was Around EP         2018-07-20
# 29                          The Nest         2018-03-15
# 15                      Plastic Love         2019-03-10
# 12             Seyda Neen (Acoustic)         2018-05-06
# 32                     Lost in Japan         2018-05-02
# 47                            PLACES         2019-03-15
# 19                  I Don't Need You         2016-07-22
# 3                               Bani         2019-05-31
# 40                     The Bad Taste         2019-04-19
# 22                     Old Fashioned         2019-02-19
# 23       If You Know That I'm Lonely         2017-09-06
# 17                     Mantra Mantra         2018-09-14
# 14                      Plastic Love         2018-12-05
# 10                     Mantra Mantra         2018-09-14

# %%
fig = plt.figure(dpi=128, figsize=(10,6))
ax = plt.gca()
long_term_top_tracks_df.plot(kind='scatter',x='popularity',y='duration_ms',color='red', ax=ax)
plt.show()

# %%
fig = plt.figure(dpi=200, figsize=(20,6))#20 untuk lebar, 6 untuk panjang dalam satuan inch
ax = plt.gca()
long_term_top_tracks_df.plot(kind='bar',x='name',y='popularity',ax=ax)
plt.show()

# %%
fig = plt.figure(dpi=200, figsize=(10,6))
ax = plt.gca()
long_term_top_tracks_df.plot(kind='line',x='artists',y='popularity',ax=ax)
plt.show()

# %% [markdown]
# # NB: tidak dapat mengambil top albums, karena yang disediakan oleh api spotify hanya top artist dan top tracks

# %% [markdown]
# # list feature

# %%
trends_set = [
    { 'ref': long_term_top_tracks_df,   'term': 'Long'   },
    { 'ref': medium_term_top_tracks_df, 'term': 'Medium' },
    { 'ref': short_term_top_tracks_df,  'term': 'Short'  }
]

trend_loudness = {}
trend_tempo = {}
trend_mode = {}
trend_danceability = {}
trend_energy = {}
trend_speechiness = {}
trend_acousticness = {}
trend_instrumentalness = {}
trend_liveness = {}
trend_valence = {}

for df_item in trends_set:
    dict_data = df_item['ref'].to_dict(orient='index')
    track_popularity = {v['id']: v['popularity'] for k,v in dict_data.items()}

    try:
        tracks_list_features = sp.audio_features(track_popularity.keys())
    except:
        print("Couldn't get Track Features Analytics")
        continue
        tracks_list_features
    track_analytics = None        
    collect_column_name = True
    for a in tracks_list_features:
        a['popularity'] = track_popularity[a['id']]
        
        if collect_column_name:
            track_analytics = pd.DataFrame(columns=list(a.keys()))
            collect_column_name = False
        track_analytics = track_analytics.append(a, ignore_index=True)
        
    trend_loudness[df_item['term']] = np.average(track_analytics['loudness'], weights=track_analytics['popularity'])
    trend_tempo[df_item['term']] = np.average(track_analytics['tempo'], weights=track_analytics['popularity'])
    trend_mode[df_item['term']] = np.average(track_analytics['mode'], weights=track_analytics['popularity'])
    trend_danceability[df_item['term']] = np.average(track_analytics['danceability'], weights=track_analytics['popularity'])
    trend_energy[df_item['term']] = np.average(track_analytics['energy'], weights=track_analytics['popularity'])
    trend_speechiness[df_item['term']] = np.average(track_analytics['speechiness'], weights=track_analytics['popularity'])
    trend_acousticness[df_item['term']] = np.average(track_analytics['acousticness'], weights=track_analytics['popularity'])
    trend_instrumentalness[df_item['term']] = np.average(track_analytics['instrumentalness'], weights=track_analytics['popularity'])
    trend_liveness[df_item['term']] = np.average(track_analytics['liveness'], weights=track_analytics['popularity'])
    trend_valence[df_item['term']] = np.average(track_analytics['valence'], weights=track_analytics['popularity'])

# %% [markdown]
# # tracks list feature table

# %%
track_analytics.head(10)
# Out:
#    danceability  energy key  loudness mode  speechiness  acousticness  \
# 0         0.702   0.692  10    -5.405    1       0.0539      0.054200
# 1         0.512   0.483   0    -7.798    1       0.0298      0.003040
# 2         0.273   0.565   2    -7.283    1       0.2480      0.516000
# 3         0.665   0.394  11   -11.567    0       0.1030      0.813000
# 4         0.376   0.473   4    -5.636    1       0.0325      0.005270
# 5         0.486   0.891   7    -4.326    1       0.0739      0.000485
# 6         0.333   0.487   7    -8.169    1       0.0342      0.147000
# 7         0.822   0.522   4    -8.744    0       0.0965      0.491000
# 8         0.136   0.338   0   -10.708    1       0.0310      0.575000
# 9         0.626   0.725  11    -7.782    0       0.1770      0.011900
#
#   instrumentalness  liveness  valence    tempo            type  \
# 0                0    0.0877   0.4190  144.896  audio_features
# 1           0.0011    0.1200   0.3670  160.009  audio_features
# 2         1.68e-06    0.0855   0.2980  179.518  audio_features
# 3           0.0414    0.1850   0.4990   82.067  audio_features
# 4          0.00162    0.1230   0.0398  148.835  audio_features
# 5         5.69e-05    0.0905   0.3740  159.977  audio_features
# 6           0.0751    0.0801   0.1550  188.908  audio_features
# 7                0    0.1010   0.0672  111.098  audio_features
# 8         2.26e-05    0.1600   0.2240  170.091  audio_features
# 9           0.0675    0.0882   0.6330  174.869  audio_features
#
#                        id                                   uri  \
# 0  2xtP8RNbo2BEMzLX7tK7aq  spotify:track:2xtP8RNbo2BEMzLX7tK7aq
# 1  0VF7YLIxSQKyNiFL3X6MmN  spotify:track:0VF7YLIxSQKyNiFL3X6MmN
# 2  2lTtnKQgjbrBA1qnOFhBkP  spotify:track:2lTtnKQgjbrBA1qnOFhBkP
# 3  2koESjC2WBc6qmfg0dmTRt  spotify:track:2koESjC2WBc6qmfg0dmTRt
# 4  7iPlcFvOMOzt6v0QvcAueZ  spotify:track:7iPlcFvOMOzt6v0QvcAueZ
# 5  2oAZlBN2CmNieXmJ1bQDYL  spotify:track:2oAZlBN2CmNieXmJ1bQDYL
# 6  5VoBizwMwcd2D68EfqxDbO  spotify:track:5VoBizwMwcd2D68EfqxDbO
# 7  54JbP4PgOMQGowCbCfjCNA  spotify:track:54JbP4PgOMQGowCbCfjCNA
# 8  3vzqs9tJQx7JoTC2bX7uae  spotify:track:3vzqs9tJQx7JoTC2bX7uae
# 9  22W4eNzgioQ4Tkz8B3v17a  spotify:track:22W4eNzgioQ4Tkz8B3v17a
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2xtP8RNbo2BE...
# 1  https://api.spotify.com/v1/tracks/0VF7YLIxSQKy...
# 2  https://api.spotify.com/v1/tracks/2lTtnKQgjbrB...
# 3  https://api.spotify.com/v1/tracks/2koESjC2WBc6...
# 4  https://api.spotify.com/v1/tracks/7iPlcFvOMOzt...
# 5  https://api.spotify.com/v1/tracks/2oAZlBN2CmNi...
# 6  https://api.spotify.com/v1/tracks/5VoBizwMwcd2...
# 7  https://api.spotify.com/v1/tracks/54JbP4PgOMQG...
# 8  https://api.spotify.com/v1/tracks/3vzqs9tJQx7J...
# 9  https://api.spotify.com/v1/tracks/22W4eNzgioQ4...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2xtP...      204168
# 1  https://api.spotify.com/v1/audio-analysis/0VF7...      217027
# 2  https://api.spotify.com/v1/audio-analysis/2lTt...      235226
# 3  https://api.spotify.com/v1/audio-analysis/2koE...      123220
# 4  https://api.spotify.com/v1/audio-analysis/7iPl...      314663
# 5  https://api.spotify.com/v1/audio-analysis/2oAZ...      192382
# 6  https://api.spotify.com/v1/audio-analysis/5VoB...      220760
# 7  https://api.spotify.com/v1/audio-analysis/54Jb...      169093
# 8  https://api.spotify.com/v1/audio-analysis/3vzq...      194276
# 9  https://api.spotify.com/v1/audio-analysis/22W4...      251061
#
#   time_signature popularity
# 0              4         77
# 1              4         74
# 2              4         72
# 3              4         66
# 4              4         65
# 5              4         62
# 6              3         61
# 7              4         56
# 8              3         55
# 9              4         55

# %%
results_analytics = pd.DataFrame(columns=['Long', 'Medium', 'Short'])
results_analytics = results_analytics.append(trend_loudness, ignore_index=True)
results_analytics = results_analytics.append(trend_tempo, ignore_index=True)
results_analytics = results_analytics.append(trend_mode, ignore_index=True)
results_analytics = results_analytics.append(trend_danceability, ignore_index=True)
results_analytics = results_analytics.append(trend_energy, ignore_index=True)
results_analytics = results_analytics.append(trend_speechiness, ignore_index=True)
results_analytics = results_analytics.append(trend_acousticness, ignore_index=True)
results_analytics = results_analytics.append(trend_instrumentalness, ignore_index=True)
results_analytics = results_analytics.append(trend_liveness, ignore_index=True)
results_analytics = results_analytics.append(trend_valence, ignore_index=True)
results_analytics.index = ['Loudness', 'Tempo', 'Modality', 'Danceability', 'Energy', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness', 'Valence']
results_analytics
# Out:
#                         Long      Medium       Short
# Loudness           -7.836709  -10.275932   -9.966065
# Tempo             123.479700  121.101730  134.824191
# Modality            0.754486    0.430459    0.601819
# Danceability        0.558388    0.605053    0.577579
# Energy              0.562476    0.449784    0.475926
# Speechiness         0.061441    0.131624    0.101683
# Acousticness        0.393850    0.375846    0.387037
# Instrumentalness    0.041446    0.505711    0.296162
# Liveness            0.166692    0.148026    0.145912
# Valence             0.394715    0.465210    0.379933

# %%
fig = plt.figure(dpi=200, figsize=(20,6))#20 untuk lebar, 6 untuk panjang dalam satuan inch
ax = plt.gca()
track_analytics.plot(kind='bar',x='popularity',y='danceability',ax=ax)
plt.show()

# %% [markdown]
# # create playlist

# %%
#NB!!!!!!!!!! gaperlu di run kalo yang awal udah di run, step ini buat jaga-jaga semisal tahap awal udah kelewat dalam waktu 1 hari
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util


cid ='e7d0b9a4df8e4f23be14e77f5537307c' # Client ID; copy this from your app created on beta.developer.spotify.com
secret = '0543a7534dd0433793c35f4231871257' # Client Secret; copy this from your app
username = 'a06fww0i1c3klv1urrq8ljmlv' # Your Spotify username

#for avaliable scopes see https://developer.spotify.com/web-api/using-scopes/
scope = 'user-library-read playlist-modify-public playlist-read-private'

redirect_uri='http://localhost:7000/callback/'#localhost bisa make 8888 kalo semisal belum terpakai, kalo 8888 udah terpakai bisa make 7000

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

token = util.prompt_for_user_token(username, scope, cid, secret, redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %%
#Create a dataframe of your playlist including tracks' names and audio features
import pandas as pd

sourcePlaylistID = '7KCs71l2qgYhOpmmvyne9k'#url link playlist, exp: https://open.spotify.com/playlist/7KCs71l2qgYhOpmmvyne9k
sourcePlaylist = sp.user_playlist(username, sourcePlaylistID);
tracks = sourcePlaylist["tracks"];
songs = tracks["items"];

track_ids = []
track_names = []

for i in range(0, len(songs)):
    if songs[i]['track']['id'] != None: # Removes the local tracks in your playlist if there is any
        track_ids.append(songs[i]['track']['id'])
        track_names.append(songs[i]['track']['name'])

features = []
for i in range(0,len(track_ids)):
    audio_features = sp.audio_features(track_ids[i])
    for track in audio_features:
        features.append(track)
        
playlist_df = pd.DataFrame(features, index = track_names)

# %%
playlist_df.head(10)
# Out:
#                                       danceability  energy  key  loudness  \
# Goose                                        0.640   0.846    9    -5.201
# Never Fight A Man With A Perm                0.254   0.945    9    -4.877
# Hot Squash                                   0.204   0.956    9    -4.386
# El Pastor                                    0.298   0.731    2    -7.520
# 23 (feat. Sasha Dobson)                      0.543   0.930    9    -3.922
# Cariño                                       0.647   0.385    0   -13.717
# Amsterdam                                    0.577   0.740    8    -4.696
# All in My Head                               0.391   0.803    9    -5.160
# spend some time alone inside my head         0.487   0.631    9    -8.036
# LOVE YOU, BYE.                               0.333   0.704    5    -7.657
#
#                                       mode  speechiness  acousticness  \
# Goose                                    0       0.0298      0.021800
# Never Fight A Man With A Perm            1       0.1530      0.000281
# Hot Squash                               0       0.4100      0.000391
# El Pastor                                1       0.0790      0.008790
# 23 (feat. Sasha Dobson)                  0       0.0407      0.000251
# Cariño                                   0       0.0295      0.396000
# Amsterdam                                0       0.0271      0.000128
# All in My Head                           0       0.0452      0.026000
# spend some time alone inside my head     1       0.0327      0.029500
# LOVE YOU, BYE.                           1       0.0386      0.163000
#
#                                       instrumentalness  liveness  valence  \
# Goose                                         0.541000    0.1160    0.508
# Never Fight A Man With A Perm                 0.000581    0.2070    0.223
# Hot Squash                                    0.001180    0.2040    0.145
# El Pastor                                     0.001450    0.0968    0.185
# 23 (feat. Sasha Dobson)                       0.038900    0.0830    0.235
# Cariño                                        0.049500    0.1170    0.662
# Amsterdam                                     0.103000    0.2390    0.335
# All in My Head                                0.040700    0.3350    0.166
# spend some time alone inside my head          0.088900    0.1110    0.367
# LOVE YOU, BYE.                                0.000000    0.1330    0.415
#
#                                         tempo            type  \
# Goose                                 110.009  audio_features
# Never Fight A Man With A Perm         155.979  audio_features
# Hot Squash                            189.408  audio_features
# El Pastor                              60.497  audio_features
# 23 (feat. Sasha Dobson)               110.918  audio_features
# Cariño                                113.985  audio_features
# Amsterdam                              98.057  audio_features
# All in My Head                        139.723  audio_features
# spend some time alone inside my head  143.892  audio_features
# LOVE YOU, BYE.                        104.092  audio_features
#
#                                                           id  \
# Goose                                 2v7iJcMoQcN40fK9XEb42q
# Never Fight A Man With A Perm         4B4CQ84BBpHK5d02cWKUb0
# Hot Squash                            0S4fWrLAjHX1t2zOVX3hQg
# El Pastor                             3Y2wHKbmVFQK7Br1EfzKGY
# 23 (feat. Sasha Dobson)               3aC4akG9L9xBqE5QiqfPNa
# Cariño                                55DyBUkjebkcYhDGfEXitR
# Amsterdam                             0pfhYSeyIrJSKTQwHYkcYX
# All in My Head                        1cTzXrRHjX72ylOtloaf6z
# spend some time alone inside my head  2Q6QGk8V57dR5AJBzm8tGy
# LOVE YOU, BYE.                        6c3xjkhvBTIHjMtCZKl5IM
#
#                                                                        uri  \
# Goose                                 spotify:track:2v7iJcMoQcN40fK9XEb42q
# Never Fight A Man With A Perm         spotify:track:4B4CQ84BBpHK5d02cWKUb0
# Hot Squash                            spotify:track:0S4fWrLAjHX1t2zOVX3hQg
# El Pastor                             spotify:track:3Y2wHKbmVFQK7Br1EfzKGY
# 23 (feat. Sasha Dobson)               spotify:track:3aC4akG9L9xBqE5QiqfPNa
# Cariño                                spotify:track:55DyBUkjebkcYhDGfEXitR
# Amsterdam                             spotify:track:0pfhYSeyIrJSKTQwHYkcYX
# All in My Head                        spotify:track:1cTzXrRHjX72ylOtloaf6z
# spend some time alone inside my head  spotify:track:2Q6QGk8V57dR5AJBzm8tGy
# LOVE YOU, BYE.                        spotify:track:6c3xjkhvBTIHjMtCZKl5IM
#
#                                                                              track_href  \
# Goose                                 https://api.spotify.com/v1/tracks/2v7iJcMoQcN4...
# Never Fight A Man With A Perm         https://api.spotify.com/v1/tracks/4B4CQ84BBpHK...
# Hot Squash                            https://api.spotify.com/v1/tracks/0S4fWrLAjHX1...
# El Pastor                             https://api.spotify.com/v1/tracks/3Y2wHKbmVFQK...
# 23 (feat. Sasha Dobson)               https://api.spotify.com/v1/tracks/3aC4akG9L9xB...
# Cariño                                https://api.spotify.com/v1/tracks/55DyBUkjebkc...
# Amsterdam                             https://api.spotify.com/v1/tracks/0pfhYSeyIrJS...
# All in My Head                        https://api.spotify.com/v1/tracks/1cTzXrRHjX72...
# spend some time alone inside my head  https://api.spotify.com/v1/tracks/2Q6QGk8V57dR...
# LOVE YOU, BYE.                        https://api.spotify.com/v1/tracks/6c3xjkhvBTIH...
#
#                                                                            analysis_url  \
# Goose                                 https://api.spotify.com/v1/audio-analysis/2v7i...
# Never Fight A Man With A Perm         https://api.spotify.com/v1/audio-analysis/4B4C...
# Hot Squash                            https://api.spotify.com/v1/audio-analysis/0S4f...
# El Pastor                             https://api.spotify.com/v1/audio-analysis/3Y2w...
# 23 (feat. Sasha Dobson)               https://api.spotify.com/v1/audio-analysis/3aC4...
# Cariño                                https://api.spotify.com/v1/audio-analysis/55Dy...
# Amsterdam                             https://api.spotify.com/v1/audio-analysis/0pfh...
# All in My Head                        https://api.spotify.com/v1/audio-analysis/1cTz...
# spend some time alone inside my head  https://api.spotify.com/v1/audio-analysis/2Q6Q...
# LOVE YOU, BYE.                        https://api.spotify.com/v1/audio-analysis/6c3x...
#
#                                       duration_ms  time_signature
# Goose                                      255455               4
# Never Fight A Man With A Perm              228832               4
# Hot Squash                                 237427               4
# El Pastor                                  310047               4
# 23 (feat. Sasha Dobson)                    250520               4
# Cariño                                     258714               4
# Amsterdam                                  252429               4
# All in My Head                             264850               4
# spend some time alone inside my head       154826               4
# LOVE YOU, BYE.                             235457               4

# %%
playlist_df=playlist_df[["id", "acousticness", "danceability", "duration_ms", 
                         "energy", "instrumentalness",  "key", "liveness",
                         "loudness", "mode", "speechiness", "tempo", "valence"]]
playlist_df.head()
# Out:
#                                                    id  acousticness  \
# Goose                          2v7iJcMoQcN40fK9XEb42q      0.021800
# Never Fight A Man With A Perm  4B4CQ84BBpHK5d02cWKUb0      0.000281
# Hot Squash                     0S4fWrLAjHX1t2zOVX3hQg      0.000391
# El Pastor                      3Y2wHKbmVFQK7Br1EfzKGY      0.008790
# 23 (feat. Sasha Dobson)        3aC4akG9L9xBqE5QiqfPNa      0.000251
#
#                                danceability  duration_ms  energy  \
# Goose                                 0.640       255455   0.846
# Never Fight A Man With A Perm         0.254       228832   0.945
# Hot Squash                            0.204       237427   0.956
# El Pastor                             0.298       310047   0.731
# 23 (feat. Sasha Dobson)               0.543       250520   0.930
#
#                                instrumentalness  key  liveness  loudness  \
# Goose                                  0.541000    9    0.1160    -5.201
# Never Fight A Man With A Perm          0.000581    9    0.2070    -4.877
# Hot Squash                             0.001180    9    0.2040    -4.386
# El Pastor                              0.001450    2    0.0968    -7.520
# 23 (feat. Sasha Dobson)                0.038900    9    0.0830    -3.922
#
#                                mode  speechiness    tempo  valence
# Goose                             0       0.0298  110.009    0.508
# Never Fight A Man With A Perm     1       0.1530  155.979    0.223
# Hot Squash                        0       0.4100  189.408    0.145
# El Pastor                         1       0.0790   60.497    0.185
# 23 (feat. Sasha Dobson)           0       0.0407  110.918    0.235

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

v=TfidfVectorizer(sublinear_tf=True, ngram_range=(1, 6), max_features=10000)
X_names_sparse = v.fit_transform(track_names)
X_names_sparse.shape
# Out:
# (51, 321)

# %%
## Change the below info for each playlist manually to get better results
# Give ratings to your tracks with respect to their playlist relevances
# Rate them from 1-10, give higher ratings to those tracks which you think best chracterizes your playlist
# If you order your playlist by relevance while creating it, this step will become easier
# So now, we will deal with a classification task
import numpy as np
playlist_df['ratings']=[10, 9, 9, 10, 8, 6, 8, 4, 3, 5, 7, 5, 5, 8, 8, 7, 8, 8, 10, 8, 10, 8, 4, 4, 4, 10, 10, 9, 8, 8, 4, 7, 9, 8, 6, 6, 9, 6, 8, 8, 9, 10, 9, 8, 8, 7, 7, 8, 9, 7, 10]
playlist_df.head()
# Out:
#                                                    id  acousticness  \
# Goose                          2v7iJcMoQcN40fK9XEb42q      0.021800
# Never Fight A Man With A Perm  4B4CQ84BBpHK5d02cWKUb0      0.000281
# Hot Squash                     0S4fWrLAjHX1t2zOVX3hQg      0.000391
# El Pastor                      3Y2wHKbmVFQK7Br1EfzKGY      0.008790
# 23 (feat. Sasha Dobson)        3aC4akG9L9xBqE5QiqfPNa      0.000251
#
#                                danceability  duration_ms  energy  \
# Goose                                 0.640       255455   0.846
# Never Fight A Man With A Perm         0.254       228832   0.945
# Hot Squash                            0.204       237427   0.956
# El Pastor                             0.298       310047   0.731
# 23 (feat. Sasha Dobson)               0.543       250520   0.930
#
#                                instrumentalness  key  liveness  loudness  \
# Goose                                  0.541000    9    0.1160    -5.201
# Never Fight A Man With A Perm          0.000581    9    0.2070    -4.877
# Hot Squash                             0.001180    9    0.2040    -4.386
# El Pastor                              0.001450    2    0.0968    -7.520
# 23 (feat. Sasha Dobson)                0.038900    9    0.0830    -3.922
#
#                                mode  speechiness    tempo  valence  ratings
# Goose                             0       0.0298  110.009    0.508       10
# Never Fight A Man With A Perm     1       0.1530  155.979    0.223        9
# Hot Squash                        0       0.4100  189.408    0.145        9
# El Pastor                         1       0.0790   60.497    0.185       10
# 23 (feat. Sasha Dobson)           0       0.0407  110.918    0.235        8

# %%
# Analyze feature importances
from sklearn.ensemble.forest import RandomForestRegressor, RandomForestClassifier

X_train = playlist_df.drop(['id', 'ratings'], axis=1)
y_train = playlist_df['ratings']
forest = RandomForestClassifier(random_state=42, max_depth=5, max_features=12) # Set by GridSearchCV below
forest.fit(X_train, y_train)
importances = forest.feature_importances_
indices = np.argsort(importances)[::-1]

# Print the feature rankings
print("Feature ranking:")
  
for f in range(len(importances)):
    print("%d. %s %f " % (f + 1, 
            X_train.columns[f], 
            importances[indices[f]]))
# Out:
# Feature ranking:
# 1. acousticness 0.207636
# 2. danceability 0.158609
# 3. duration_ms 0.107771
# 4. energy 0.099464
# 5. instrumentalness 0.079962
# 6. key 0.066289
# 7. liveness 0.062205
# 8. loudness 0.060924
# 9. mode 0.058380
# 10. speechiness 0.047071
# 11. tempo 0.045309
# 12. valence 0.006380
# c:\programdata\miniconda\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# Apply pca to the scaled train set first

from sklearn import decomposition
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style='white')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

X_scaled = StandardScaler().fit_transform(X_train)

pca = decomposition.PCA().fit(X_scaled)

# %%
# Fit your dataset to the optimal pca
pca1 = decomposition.PCA(n_components=8)
X_pca = pca1.fit_transform(X_scaled)

# %%
# You may want to check the results of TSNE also
from sklearn.manifold import TSNE

tsne = TSNE(random_state=17)
X_tsne = tsne.fit_transform(X_scaled)

# %%
from scipy.sparse import csr_matrix, hstack

X_train_last = csr_matrix(hstack([X_pca, X_names_sparse])) # Check with X_tsne + X_names_sparse also

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV
import warnings
warnings.filterwarnings('ignore')

# Initialize a stratified split for the validation process
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
# Decision Trees First
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier()

tree_params = {'max_depth': range(1,11), 'max_features': range(4,19)}

tree_grid = GridSearchCV(tree, tree_params, cv=skf, n_jobs=-1, verbose=True)

tree_grid.fit(X_train_last, y_train)
tree_grid.best_estimator_, tree_grid.best_score_
# Out:
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 664 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 750 out of 750 | elapsed:    4.4s finished
# (DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=8,
#                         max_features=10, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=None, splitter='best'),
#  0.35294117647058826)

# %%
# Random Forests second

parameters = {'max_features': [4, 7, 8, 10], 'min_samples_leaf': [1, 3, 5, 8], 'max_depth': [3, 5, 8]}
rfc = RandomForestClassifier(n_estimators=100, random_state=42, 
                             n_jobs=-1, oob_score=True)
gcv1 = GridSearchCV(rfc, parameters, n_jobs=-1, cv=skf, verbose=1)
gcv1.fit(X_train_last, y_train)
gcv1.best_estimator_, gcv1.best_score_
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=-1)]: Done 240 out of 240 | elapsed:   22.8s finished
# (RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                         max_depth=3, max_features=4, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=100,
#                         n_jobs=-1, oob_score=True, random_state=42, verbose=0,
#                         warm_start=False), 0.3137254901960784)

# %%
#kNN third
from sklearn.neighbors import KNeighborsClassifier

knn_params = {'n_neighbors': range(1, 10)}
knn = KNeighborsClassifier(n_jobs=-1)

knn_grid = GridSearchCV(knn, knn_params, cv=skf, n_jobs=-1, verbose=True)
knn_grid.fit(X_train_last, y_train)
knn_grid.best_params_, knn_grid.best_score_
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:    4.9s finished
# ({'n_neighbors': 7}, 0.3137254901960784)

# %%
rec_tracks = []
for i in playlist_df['id'].values.tolist():
    rec_tracks += sp.recommendations(seed_tracks=[i], limit=int(len(playlist_df)/2))['tracks'];

rec_track_ids = []
rec_track_names = []
for i in rec_tracks:
    rec_track_ids.append(i['id'])
    rec_track_names.append(i['name'])

rec_features = []
for i in range(0,len(rec_track_ids)):
    rec_audio_features = sp.audio_features(rec_track_ids[i])
    for track in rec_audio_features:
        rec_features.append(track)
        
rec_playlist_df = pd.DataFrame(rec_features, index = rec_track_ids)
rec_playlist_df.head()
# Out:
#                         danceability  energy  key  loudness  mode  \
# 0Jf3QiP8WrXEoFsaUsJi0b         0.421   0.931    0    -4.569     1
# 2a8NBThJj28YrJIqDzYJsB         0.566   0.968    3    -3.600     0
# 2HwouROQIVSHXwE6PZaCzC         0.568   0.877    4    -7.043     0
# 0mnyjCNu9XUi5dv0JD3UqM         0.432   0.664    9    -7.281     0
# 2fVIQFxGHSJHR5RYG4SMpI         0.447   0.984    1    -4.225     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 0Jf3QiP8WrXEoFsaUsJi0b       0.0397      0.000451          0.287000    0.0774
# 2a8NBThJj28YrJIqDzYJsB       0.0521      0.014700          0.000000    0.1110
# 2HwouROQIVSHXwE6PZaCzC       0.0526      0.003570          0.214000    0.1250
# 0mnyjCNu9XUi5dv0JD3UqM       0.0363      0.002960          0.758000    0.1170
# 2fVIQFxGHSJHR5RYG4SMpI       0.1640      0.000222          0.000012    0.0893
#
#                         valence    tempo            type  \
# 0Jf3QiP8WrXEoFsaUsJi0b    0.393   90.039  audio_features
# 2a8NBThJj28YrJIqDzYJsB    0.555  124.996  audio_features
# 2HwouROQIVSHXwE6PZaCzC    0.172  108.524  audio_features
# 0mnyjCNu9XUi5dv0JD3UqM    0.277  196.083  audio_features
# 2fVIQFxGHSJHR5RYG4SMpI    0.128  144.034  audio_features
#
#                                             id  \
# 0Jf3QiP8WrXEoFsaUsJi0b  0Jf3QiP8WrXEoFsaUsJi0b
# 2a8NBThJj28YrJIqDzYJsB  2a8NBThJj28YrJIqDzYJsB
# 2HwouROQIVSHXwE6PZaCzC  2HwouROQIVSHXwE6PZaCzC
# 0mnyjCNu9XUi5dv0JD3UqM  0mnyjCNu9XUi5dv0JD3UqM
# 2fVIQFxGHSJHR5RYG4SMpI  2fVIQFxGHSJHR5RYG4SMpI
#
#                                                          uri  \
# 0Jf3QiP8WrXEoFsaUsJi0b  spotify:track:0Jf3QiP8WrXEoFsaUsJi0b
# 2a8NBThJj28YrJIqDzYJsB  spotify:track:2a8NBThJj28YrJIqDzYJsB
# 2HwouROQIVSHXwE6PZaCzC  spotify:track:2HwouROQIVSHXwE6PZaCzC
# 0mnyjCNu9XUi5dv0JD3UqM  spotify:track:0mnyjCNu9XUi5dv0JD3UqM
# 2fVIQFxGHSJHR5RYG4SMpI  spotify:track:2fVIQFxGHSJHR5RYG4SMpI
#
#                                                                track_href  \
# 0Jf3QiP8WrXEoFsaUsJi0b  https://api.spotify.com/v1/tracks/0Jf3QiP8WrXE...
# 2a8NBThJj28YrJIqDzYJsB  https://api.spotify.com/v1/tracks/2a8NBThJj28Y...
# 2HwouROQIVSHXwE6PZaCzC  https://api.spotify.com/v1/tracks/2HwouROQIVSH...
# 0mnyjCNu9XUi5dv0JD3UqM  https://api.spotify.com/v1/tracks/0mnyjCNu9XUi...
# 2fVIQFxGHSJHR5RYG4SMpI  https://api.spotify.com/v1/tracks/2fVIQFxGHSJH...
#
#                                                              analysis_url  \
# 0Jf3QiP8WrXEoFsaUsJi0b  https://api.spotify.com/v1/audio-analysis/0Jf3...
# 2a8NBThJj28YrJIqDzYJsB  https://api.spotify.com/v1/audio-analysis/2a8N...
# 2HwouROQIVSHXwE6PZaCzC  https://api.spotify.com/v1/audio-analysis/2Hwo...
# 0mnyjCNu9XUi5dv0JD3UqM  https://api.spotify.com/v1/audio-analysis/0mny...
# 2fVIQFxGHSJHR5RYG4SMpI  https://api.spotify.com/v1/audio-analysis/2fVI...
#
#                         duration_ms  time_signature
# 0Jf3QiP8WrXEoFsaUsJi0b       256333               4
# 2a8NBThJj28YrJIqDzYJsB       231500               4
# 2HwouROQIVSHXwE6PZaCzC       327373               4
# 0mnyjCNu9XUi5dv0JD3UqM       172437               4
# 2fVIQFxGHSJHR5RYG4SMpI       193333               4

# %%
X_test_names = v.transform(rec_track_names)

# %%
rec_playlist_df=rec_playlist_df[["acousticness", "danceability", "duration_ms", 
                         "energy", "instrumentalness",  "key", "liveness",
                         "loudness", "mode", "speechiness", "tempo", "valence"]]

# %%
# Make predictions
tree_grid.best_estimator_.fit(X_train_last, y_train)
rec_playlist_df_scaled = StandardScaler().fit_transform(rec_playlist_df)
rec_playlist_df_pca = pca1.transform(rec_playlist_df_scaled)
X_test_last = csr_matrix(hstack([rec_playlist_df_pca, X_test_names]))
y_pred_class = tree_grid.best_estimator_.predict(X_test_last)

# %%
rec_playlist_df['ratings']=y_pred_class
rec_playlist_df = rec_playlist_df.sort_values('ratings', ascending = False)
rec_playlist_df = rec_playlist_df.reset_index()

# Pick the top ranking tracks to add your new playlist 9, 10 will work
recs_to_add = rec_playlist_df[rec_playlist_df['ratings']>=9]['index'].values.tolist()

# %%
recs_to_add = rec_playlist_df[rec_playlist_df['ratings']==8]['index'].values.tolist()

# %%
len(rec_tracks), rec_playlist_df.shape, len(recs_to_add)
# Out:
# (1275, (1275, 14), 527)

# %%
rec_array = np.reshape(recs_to_add, (17, 31))

# %%
playlist_recs = sp.user_playlist_create(username, 
                                        name='PCA + tf-idf + DT - Recommended Songs for Playlist - {}'.format(sourcePlaylist['name']))

# %%
for i in rec_array:
    sp.user_playlist_add_tracks(username, playlist_recs['id'], i);
